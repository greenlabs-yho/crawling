# %%
import vertexai
from google.cloud import aiplatform
from langchain.llms.vertexai import VertexAI
from langchain.output_parsers.boolean import BooleanOutputParser
from langchain.prompts import PromptTemplate
import pandas as pd

PROJECT_ID = "grainscanner"  # @param {type:"string"}
REGION = "asia-northeast3"  # @param {type:"string"}

# Initialize Vertex AI SDK
vertexai.init(project=PROJECT_ID, location=REGION)

# Text model instance integrated with langChain


def verify_url(llm, name, url, meta):
    boolean_parser = BooleanOutputParser()

    filter_template = """
        Goal: Make sure the URL is the correct URL
        Data given: Company name, URL, homepage metadata
        Process
        1. Verifying the URL by verifying that the company name and URL are related
        2. Verification by verifying that the company name and homepage metadata are correct

        Format instructions:
        If it's related, return it to YES, if not, return it to NO.

        Company name:{name}
        URL:{url}
        homepage metadata:{meta}

        output:
    """

    filter_prompt_template = PromptTemplate(
        input_variables=["name", "url", "meta"],
        template=filter_template,
        output_parser=boolean_parser,
        # partial_variables={
        #     "format_instructions": boolean_parser.get_format_instructions()
        # }
    )

    chain = filter_prompt_template | llm | boolean_parser

    try:
        result_additional_filter_json = chain.invoke(
            {"name": name, "url": url, "meta": meta}
        )
    except Exception as e:
        print(f"error : {e}")

    return result_additional_filter_json

# %%
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
df = pd.read_csv("/Users/yoonhae/Downloads/중국_20240202_0959.csv")

for i in range(len(df)):
    comp_name = df.loc[i, "comp_name"]
    homepage = df.loc[i, "homepage"]

    try:
        if (
            pd.notna(homepage) and homepage.strip()
        ):  # homepage가 비어있지 않고, 공백이 아닌 경우
            response = requests.get(homepage, timeout=6)
            soup = BeautifulSoup(response.text, "html.parser")
            metadata = ""
            for meta in soup.find_all("meta"):
                metadata += str(meta.attrs)

            llm = VertexAI(
                model_name="text-bison@001",
                max_output_tokens=1024,
                temperature=0,
                top_p=0.8,
                top_k=40,
                verbose=True,
                location=REGION,
            )

            is_url = verify_url(llm, comp_name, homepage, metadata)
            df.loc[i, "is_url"] = is_url
            print(comp_name, homepage, is_url)
    except requests.exceptions.MissingSchema:
        # 잘못된 URL 형식에 대한 예외 처리
        print(f"잘못된 URL 형식: {homepage}")
        continue
    except Exception as e:
        # 기타 예외 처리
        print(f"예외 발생: {e}")
        continue
# Out:
# /Users/yoonhae/.pyenv/versions/3.8.12/envs/crawling/lib/python3.8/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.vertexai.VertexAI` was deprecated in langchain-community 0.0.12 and will be removed in 0.2.0. An updated version of the class exists in the langchain-google-vertexai package and should be used instead. To use it run `pip install -U langchain-google-vertexai` and import as `from langchain_google_vertexai import VertexAI`.
#   warn_deprecated(
# VITERRA LTD https://www.viterra.com/ True
# SHANNON AGENCY'S PTY LTD https://www.zoominfo.com/c/shannon-bros/371459344 False
# SEMAPHORE CONTAINER SERVICES PTY LTD https://www.semaphorecs.com.au/ True
# ROBINSON GRAIN TRADING CO PTY LTD https://www.robinsongrain.com.au/ True
# QUEENSLAND BULK TERMINALS PTY LTD http://www.qldbulkterminals.com/ True
# GRAINPAC PTY LTD http://www.grainpac.com.au/ True
# GRAINLINK (NSW) PTY LTD https://abr.business.gov.au/ABN/View/22094464516 False
# CANOWINDRA PRODUCE CO PTY LTD https://www.canowindraproduce.com.au/ True
# INDEPENDENT GRAIN HANDLERS PTY LTD https://soilms.com.au/contact/ False
# MOUNTAIN INDUSTRIES PTY LTD https://au.linkedin.com/company/mountain-industries-pty-ltd True
# 예외 발생: Failed to parse: 제공된 JSON 데이터에는 "JAMES DOUGLAS WALLACE, ANNETTE RUTH WALLACE, JUSTIN ERIC WALLACE, LORELEI WALLACE"라는 이름의 회사 홈페이지 URL이 포함되어 있지 않습니다. 따라서 빈 문자열("")을 반환합니다.
# MOUNTAIN INDUSTRIES PTY LTD https://au.linkedin.com/company/mountain-industries-pty-ltd True
# PREMIUM GRAIN HANDLERS PTY LTD http://www.pgh.com.au/ True
# 예외 발생: HTTPSConnectionPool(host='qube.com.au', port=443): Max retries exceeded with url: /ports/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)')))
# CARGILL MALT ASIA PACIFIC PTY LTD https://www.bloomberg.com/profile/company/6928949Z:AU False
# TAMMA GRAINS AUSTRALIA PTY LTD http://east-pingelly-wa.place-advisor.com/tamma-grains-australia-pty-ltd/ False
# SHANNON AGENCY'S PTY LTD https://www.zoominfo.com/c/shannon-bros/371459344 False
# NEWCASTLE AGRI TERMINAL PTY LTD https://www.naterminal.com.au/ True
# GRAINLINK (NSW) PTY LTD https://abr.business.gov.au/ABN/View/22094464516 False
# BUNGE GRAIN SERVICES (BUNBURY) PTY LTD https://www.bunge.com/Australia True
# VITERRA PACKING AND PROCESSING PTY LTD https://viterra.com.au/ True
# WOODS PROCESSING PTY LTD https://www.dnb.com/business-directory/company-profiles.woods_grain_pty_ltd.0b52f7a62ad0133fced7e3caa3d2dc3f.html False
# SWAN PACK PTY LTD https://www.swancoils.com.au/ True
# AUSTRALIA MILLING GROUP PTY LTD https://www.dnb.com/business-directory/company-profiles.australia_milling_group_pty_ltd.14240a3c22daa6b2696ae02ae397435a.html True
# CHS BROADBENT PTY LTD https://www.chsbroadbent.com/ True
# THE WIMMERA GRAIN COMPANY PTY LTD https://www.wimmerahealthgrain.com.au/ True
# GRAINCORP OPERATIONS LIMITED https://www.graincorp.com.au/ True
# CO-OPERATIVE BULK HANDLING LTD https://www.cbh.com.au/ True
# GRAINCORP OPERATIONS LIMITED https://www.graincorp.com.au/ True
# GRAINCORP OPERATIONS LIMITED https://www.graincorp.com.au/ True
# VITERRA OPERATIONS PTY LTD https://viterra.com.au/ True
# GRAINCORP OPERATIONS LIMITED https://www.graincorp.com.au/ True
# VITERRA LTD https://www.viterra.com/ True
# VITERRA LTD https://www.viterra.com/ True
# VITERRA LTD https://www.viterra.com/ True
# VITERRA LTD https://www.viterra.com/ True
# VITERRA LTD https://www.viterra.com/ True
# CO-OPERATIVE BULK HANDLING LTD https://www.cbh.com.au/ True
# CO-OPERATIVE BULK HANDLING LTD https://www.cbh.com.au/ True
# CO-OPERATIVE BULK HANDLING LTD https://www.cbh.com.au/ True
# GRAINCORP OPERATIONS LTD https://www.graincorp.com.au/ True
# GRAINCORP OPERATIONS LIMITED https://www.graincorp.com.au/ True
# LAKAPUT BULK STORAGE PTY LTD https://www.scribd.com/doc/187129789/Warehouse-Transfer-Form False
# AGRIFOOD TECHNOLOGY PTY LTD https://www.zoominfo.com/c/agrifood-technology/2296201 False
# AGT FOODS AUSTRALIA http://www.agtfoods.com/au True
# AGRIPAK PTY LTD http://agripak.com.au/ True
# OADASH PTY LTD https://www.ngr.com.au/growers/data-subscribers/ False
# QUEENSLAND COTTON CORPORATION LTD https://qcotton.com.au/ True
# RODNEY'S ENTERPRISES PTY LTD & RODNEY'S TRANSPORT SERVICE (AUSTRALIA) PTY LTD https://rodneystransport.com.au/ True
# GEHRKE GRAINS & TRANSPORT PTY LTD http://www.qam.org.au/gehrke-grains--transport-pty-ltd.html True
# 예외 발생: Failed to parse: 제공된 JSON 데이터에는 "GRAINFORCE COMMODITIES PTY LTD"라는 이름의 회사 홈페이지 URL이 포함되어 있지 않습니다. 따라서 빈 문자열("")을 반환합니다.
# 예외 발생: HTTPSConnectionPool(host='www.whitepages.com.au', port=443): Read timed out. (read timeout=6)
# GRAINCORP OPERATIONS LTD https://www.graincorp.com.au/ True
# HAVENGRAIN PTY LTD https://www.grainhart.com.au/ True
# ACCESS GRAIN PTY LTD https://www.accessgrain.com.au/ True
# 예외 발생: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# VITERRA PACKING AND PROCESSING PTY LTD https://viterra.com.au/ True
# FLETCHER INTERNATIONAL EXPORTS PTY LTD https://www.fletchint.com.au/ True
# OADASH PTY LTD https://www.ngr.com.au/growers/data-subscribers/ False
# OADASH PTY LTD https://www.ngr.com.au/growers/data-subscribers/ False
# AUSTRALIAN SUPERINTENDENCE COMPANY PTY LTD https://www.asc.co/ True
# CARGILL MALT ASIA PACIFIC PTY LTD https://www.bloomberg.com/profile/company/6928949Z:AU False
# RIVERINA (AUSTRALIA) PTY LTD    https://www.riverina.com.au/ True
# LINX CARGO CARE PTY LTD https://linxcc.com.au/ True
# AUSTRALIAN GRAIN EXPORT PTY LTD https://www.australiangrainexport.com.au/ True
# CARPENDALE COMMODITIES PTY LTD https://carpendale.com.au/ True
# GRAIN DIRECT AUSTRALIA https://directgrain.com.au/ True
# ESPERANCE QUALITY GRAINS PTY LTD https://esperancequalitygrains.com/ True
# SEMAPHORE CONTAINER SERVICES PTY LTD https://www.semaphorecs.com.au/ True
# CO-OPERATIVE BULK HANDLING LTD https://www.cbh.com.au/ True
# CONTINENTAL GRAIN HANDLING PTY LTD https://www.farmweekly.com.au/story/6939913/cgh-to-close-after-selling-facility/ False
# 예외 발생: Failed to parse: 제공된 JSON 데이터에는 "NARRAKINE WESTERN CHOICE PTY LTD"라는 이름의 회사 홈페이지 URL이 포함되어 있지 않습니다. 따라서 빈 문자열("")을 반환합니다.

# %%
df
# Out:
#       no                             comp_name           city state  \
# 0   1008         AGRIGRAIN (COONAMBLE) PTY LTD      COONAMBLE   NSW
# 1   1038                           VITERRA LTD  PORT ADELAIDE   SA
# 2   1076              SHANNON AGENCY'S PTY LTD         BEULAH   VIC
# 3   1078  SEMAPHORE CONTAINER SERVICES PTY LTD       RICHMOND   SA
# 4   1089     ROBINSON GRAIN TRADING CO PTY LTD          DUBBO   NSW
# ..   ...                                   ...            ...   ...
# 95  1334      ESPERANCE QUALITY GRAINS PTY LTD      ESPERANCE    WA
# 96  2397  SEMAPHORE CONTAINER SERVICES PTY LTD        OSBORNE    SA
# 97  3905        CO-OPERATIVE BULK HANDLING LTD   FORRESTFIELD   WA
# 98  1729    CONTINENTAL GRAIN HANDLING PTY LTD     BIBRA LAKE   WA
# 99  3112      NARRAKINE WESTERN CHOICE PTY LTD       WILLIAMS    WA
#
#                                              homepage is_url
# 0                                                 NaN    NaN
# 1                            https://www.viterra.com/   True
# 2   https://www.zoominfo.com/c/shannon-bros/371459344  False
# 3                     https://www.semaphorecs.com.au/   True
# 4                   https://www.robinsongrain.com.au/   True
# ..                                                ...    ...
# 95                https://esperancequalitygrains.com/   True
# 96                    https://www.semaphorecs.com.au/   True
# 97                            https://www.cbh.com.au/   True
# 98  https://www.farmweekly.com.au/story/6939913/cg...  False
# 99  제공된 JSON 데이터에는 "NARRAKINE WESTERN CHOICE PTY L...    NaN
#
# [100 rows x 6 columns]
